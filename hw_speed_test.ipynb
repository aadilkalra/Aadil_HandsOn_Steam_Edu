# %%
print("Typing test assignment answer")
# Out:
# Typing test assignment answer

# %%
# 1 user input - choice
# 2 choice check - sentence and then user respone
# 3 time taken - parallely 
# 4 accuracy check - 
        # if 70> accuracy: complete the sentence.
        # else print time and accuracy.

# %%
# TO DO 
# 1. Ask the user if they want to change the category - 1, 2, no , toh proceed with the same category.
# 2. Accuracy check - complete the function 

def accuracy_check(sentence, user_response):
    # Calculate the number of correct characters
    correct = 0

    for i in range (min(len(user_response),len(sentence))):
        if user_response[i] == sentence[i]:
            correct += 1

    accuracy = (correct / len(sentence)) * 100
    return accuracy

# %%
import random
import time

animal_sentence = [  "The fox jumps over a lazy dog.",
           "A tiger walks through the jungle.",
            "The owl sits quietly on a tree.",
            "A cat chases a small mouse.",
            "The horse runs across the field." ]

space_sentence= [  "The rocket launched into space.",
"Stars shine brightly in the night sky.",
"The astronaut floated inside the spacecraft.",
"Earth revolves around the sun.",
"A comet travels across the galaxy." ]

print("Enter your choice-")
print("1.Animal Sentence")
print("2.Space Sentence")

choice=input("Your choice: ") # takes choice of the user animal/space list
sentence = "" # initialising placeholder for sentence

if choice == "1":
  sentence = random.choice(animal_sentence)

elif choice == "2":
  sentence = random.choice(space_sentence)

else :
  print("Incorrect choice, try again")

if sentence: # if the sentence is not blank or empty
  while True:
    print(sentence)
    start_time = time.time() 
    user_input = input(sentence) # takes user input for the sentence
    end_time = time.time() 
    time_taken = end_time - start_time # calculates time taken to type the sentence
    
    accuracy = accuracy_check(sentence, user_input) # function call for accuracy check
    if accuracy > 70:
      print(f"Time taken: {time_taken:.2f} seconds, Accuracy: {accuracy:.2f}%")
    else:
      print("Please write the complete sentence.")
      
    if user_input.lower() == 'exit':
      print("Exiting the typing test.")
      break # break is used to stop the execution of the loop

    print("Do you want to change the category?")
    print("Enter 1 for Animal")
    print("Enter 2 for Space")
    print("Enter 'no' to continue with same category")

    change = input("Your choice: ")

    if change == "1":
      sentence = random.choice(animal_sentence)

    elif change == "2":
       sentence = random.choice(space_sentence)

    elif change == "no":
      pass


else:
  print("Incorrect choice, try again")


# # METHOD 2
# if not sentence:
#   print("Incorrect choice, try again")
# else:
#   print(sentence)
#   start_time = time.time() 
#   user_input = input("Type the above sentence: ") # takes user input for the sentence
#   end_time = time.time() 
#   time_taken = end_time - start_time # calculates time taken to type the sentence
# Out:
# Enter your choice-
# 1.Animal Sentence
# 2.Space Sentence
# The owl sits quietly on a tree.
# Please write the complete sentence.
# Do you want to change the category?
# Enter 1 for Animal
# Enter 2 for Space
# Enter 'no' to continue with same category
# Earth revolves around the sun.
# Please write the complete sentence.
# Do you want to change the category?
# Enter 1 for Animal
# Enter 2 for Space
# Enter 'no' to continue with same category
# Earth revolves around the sun.
# Time taken: 16.05 seconds, Accuracy: 96.67%
# Do you want to change the category?
# Enter 1 for Animal
# Enter 2 for Space
# Enter 'no' to continue with same category
# Earth revolves around the sun.
# Please write the complete sentence.
# Exiting the typing test.
